# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster

maps = pd.read_excel('localizacoes.xlsx')
maps
# Out:
#    Cód                                   Localizacao   Latitude  Longetude
# 0    1                                          APAE -29.691053 -53.864427
# 1    2                  Caps Infantil O Equilibrista -29.695255 -53.801872
# 2    3               Escola Antônio Francisco Lisbôa -29.688296 -53.796115
# 3    4  Hospital Universitário de Santa Maria - UFSM -29.714465 -53.717590

# %%
mapa = folium.Map(
    location=[-29.690118694508637, -53.80483576062766],
    tiles="OpenStreetMap",
    zoom_start=13
)

iconeGabrieli = folium.features.CustomIcon('https://raw.githubusercontent.com/LeonardoFdSantos/map-gabrieli-tcc/main/Localizacao_Gabrieli.png',icon_size=(75,75), icon_anchor=(37.5, 72), popup_anchor=(0,-70))

folium.Marker(location= [-29.713735225021466, -53.71281461789054],
    popup="Prédio 26D - CCS - Terapia Ocupacional - UFSM",
    tooltip='Prédio 26D - CCS - Terapia Ocupacional - UFSM',
    icon=(iconeGabrieli)
    ).add_to(mapa)

# %%
for index, creche in maps.iterrows():
      print(creche)
      folium.Marker(location= [creche['Latitude'], creche['Longetude']],
                  popup = str(creche['Localizacao']),
                  tooltip = str(creche['Localizacao']),
                  icon=(folium.features.CustomIcon('https://raw.githubusercontent.com/LeonardoFdSantos/map-gabrieli-tcc/main/Localizacao_Gabrieli.png',icon_size=(75,75), icon_anchor=(37.5, 72), popup_anchor=(0,-70)))).add_to(mapa)
# Out:
# Cód                    1
# Localizacao         APAE
# Latitude      -29.691053
# Longetude     -53.864427
# Name: 0, dtype: object
# Cód                                       2
# Localizacao    Caps Infantil O Equilibrista
# Latitude                         -29.695255
# Longetude                        -53.801872
# Name: 1, dtype: object
# Cód                                          3
# Localizacao    Escola Antônio Francisco Lisbôa
# Latitude                            -29.688296
# Longetude                           -53.796115
# Name: 2, dtype: object
# Cód                                                       4
# Localizacao    Hospital Universitário de Santa Maria - UFSM
# Latitude                                         -29.714465
# Longetude                                         -53.71759
# Name: 3, dtype: object

# %%
mapa.save(outfile="index.html")

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8666ae49de8d2f19dfe3f2a316655d4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8666ae49de8d2f19dfe3f2a316655d4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8666ae49de8d2f19dfe3f2a316655d4f = L.map(
#                 &quot;map_8666ae49de8d2f19dfe3f2a316655d4f&quot;,
#                 {
#                     center: [-29.690118694508637, -53.80483576062766],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd8f64e916e8af8e1d3b669d27e6b86b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8666ae49de8d2f19dfe3f2a316655d4f);
#
#
#             var marker_fbf08d9fdbb7348fa4c4f83a9a2789f6 = L.marker(
#                 [-29.713735225021466, -53.71281461789054],
#                 {}
#             ).addTo(map_8666ae49de8d2f19dfe3f2a316655d4f);
#
#
#         var custom_icon_476c4cacd7944f6924ee70df24ca29bc = L.icon({&quot;iconAnchor&quot;: [37.5, 72], &quot;iconSize&quot;: [75, 75], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/LeonardoFdSantos/map-gabrieli-tcc/main/Localizacao_Gabrieli.png&quot;, &quot;popupAnchor&quot;: [0, -70]});
#         marker_fbf08d9fdbb7348fa4c4f83a9a2789f6.setIcon(custom_icon_476c4cacd7944f6924ee70df24ca29bc);
#
#
#         var popup_dbec6c71a98594b93c24f6737c19b77a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_55ae6cc33d062ba9947a66a81ec0a05e = $(`&lt;div id=&quot;html_55ae6cc33d062ba9947a66a81ec0a05e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Prédio 26D - CCS - Terapia Ocupacional - UFSM&lt;/div&gt;`)[0];
#                 popup_dbec6c71a98594b93c24f6737c19b77a.setContent(html_55ae6cc33d062ba9947a66a81ec0a05e);
#
#
#
#         marker_fbf08d9fdbb7348fa4c4f83a9a2789f6.bindPopup(popup_dbec6c71a98594b93c24f6737c19b77a)
#         ;
#
#
#
#
#             marker_fbf08d9fdbb7348fa4c4f83a9a2789f6.bindTooltip(
#                 `&lt;div&gt;
#                      Prédio 26D - CCS - Terapia Ocupacional - UFSM
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0d1260bd80b710bd2ac45992d79bbbfb = L.marker(
#                 [-29.6910525, -53.8644269],
#                 {}
#             ).addTo(map_8666ae49de8d2f19dfe3f2a316655d4f);
#
#
#         var custom_icon_006cd1ce4b630c92a8b9c5f7dbf0d67c = L.icon({&quot;iconAnchor&quot;: [37.5, 72], &quot;iconSize&quot;: [75, 75], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/LeonardoFdSantos/map-gabrieli-tcc/main/Localizacao_Gabrieli.png&quot;, &quot;popupAnchor&quot;: [0, -70]});
#         marker_0d1260bd80b710bd2ac45992d79bbbfb.setIcon(custom_icon_006cd1ce4b630c92a8b9c5f7dbf0d67c);
#
#
#         var popup_caa1951545bfd26a9662255382d058fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2508d6a5f2e8ebc4673b8f22b3a9ad1 = $(`&lt;div id=&quot;html_e2508d6a5f2e8ebc4673b8f22b3a9ad1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;APAE&lt;/div&gt;`)[0];
#                 popup_caa1951545bfd26a9662255382d058fc.setContent(html_e2508d6a5f2e8ebc4673b8f22b3a9ad1);
#
#
#
#         marker_0d1260bd80b710bd2ac45992d79bbbfb.bindPopup(popup_caa1951545bfd26a9662255382d058fc)
#         ;
#
#
#
#
#             marker_0d1260bd80b710bd2ac45992d79bbbfb.bindTooltip(
#                 `&lt;div&gt;
#                      APAE
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cab7ebca41f9430e04a1ac3ecf8e8034 = L.marker(
#                 [-29.6952547, -53.8018717],
#                 {}
#             ).addTo(map_8666ae49de8d2f19dfe3f2a316655d4f);
#
#
#         var custom_icon_bbdfe8432fc6b8ad4a4fc152180b079f = L.icon({&quot;iconAnchor&quot;: [37.5, 72], &quot;iconSize&quot;: [75, 75], &quot;iconUrl&quot;: &quot;https://raw.githubusercontent.com/LeonardoFdSantos/map-gabrieli-tcc/main/Localizacao_Gabrieli.png&quot;, &quot;popupAnchor&quot;: [0, -70]});
#         marker_cab7ebca41f9430e04a1ac3ecf8e8034.setIcon(custom_icon_bbdfe8432fc6b8ad4a4fc152180b079f);
#
#
#         var popup_5a34f3293effd0aaab52de6f4d457952 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_832874666ee3c3a8c55048fc2e5a7e36 = $(`&lt;div id=&quot;html_832874666ee3c3a8c55048fc2e5a7e36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Caps Infantil O Equilibrista&lt;/div&gt;`)[0];
#                 popup_5a34f3293effd0aaab52de6f4d457952.setContent(html_832874666ee3c3a8c55048fc2e5a7e36);
